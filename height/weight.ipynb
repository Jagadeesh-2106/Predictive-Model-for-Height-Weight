# %% [markdown]
# <a href="https://colab.research.google.com/github/Jagadeesh-2106/Predictive-Model-for-Height-Weight/blob/main/height/weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Build a predictive model for determining height or weight of a person.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data=pd.read_csv('/content/heights.csv')

# %%
data.head()

# %%
x=data['weight'].values.reshape(-1,1)
y=data['height'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()#importing libraries
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)

# %%
weight=float(input("Enter weight in kg"))
predicted_height=model.predict([[weight]])
print("Predicted height is",predicted_height)

# %%
#plotting output
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,color='red')
plt.xlabel("Actual height")
plt.ylabel("Predicted value")
plt.show()

# %%
x1=data['height'].values.reshape(-1,1)
y1=data['weight'].values

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
model=LinearRegression()#importing libraries
model.fit(x1_train,y1_train)

# %%
y1_pred=model.predict(x1_test)

# %%
height=float(input("Enter height in cm"))
predicted_weight=model.predict([[height]])
print("Predicted weight is",predicted_weight)

# %%
#plotting output
plt.scatter(x1_test,y1_test)
plt.plot(x1_test,y1_pred,color='red')
plt.xlabel("Actual height")
plt.ylabel("Predicted value")
plt.show()

# %%
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("RMSE:",rmse)
print("R2 Score:",r2)
